# %%
# call yelp api
def yelp_call(url_params, api_key):
    # use .get() to call url and set 'response'
    response = requests.get(url, headers=headers, params=url_params)
    # return json file from yelp api for all businesses
    return response.json()['businesses']

# %%
# parse yelp data according to parameters
def parse_data(list_of_data):
    # create a container to hold our parsed data
    businesses = []
    # loop through our business  
    for business in list_of_data:
        # parse each individual business into a tuple
        biz_tuple = (business['name'],
                     business['location']['zip_code'],
                     business['rating']
                    )
        # add each individual business tuple to our data container
        businesses.append(biz_tuple)
    # return the container with all of the parsed results
    return businesses

# %%
# parse yelp data according to parameters
def parse_data_comp_boston(list_of_data):
    # create a container to hold our parsed data
    businesses = []
    # loop through our business  
    for business in list_of_data:
        # parse each individual business into a tuple
        biz_tuple = (
                    business['name'],
                    business['location']['zip_code'],
                    business['rating'],
                    business['price'],
                    business['open_at'],
                    business['atributes']['Street Parking',
                                          'Private Lot Parking', 
                                          'Bike Parking',
                                          'Wheelchair Accessible',
                                          'Offers Military Discount',
                                          'Open to All']
                    )
        # add each individual business tuple to our data container
        businesses.append(biz_tuple)
        # put parsed result into DataFrame 'results'
        parsed_results = parse_data(data['businesses'])
        results = pd.DataFrame(parsed_results)
        # name DataFrame columns
        results.columns = ['name', 'zipcode', 'rating', 'price', 'open_at', 
                           'Street Parking','Private Lot Parking', 'Bike Parking', 
                           'Wheelchair Accessible','Offers Military Discount', 'Open to All'
                          ]
    # return the container with all of the parsed results and save file as csv
    return results.to_csv("/Competitors_Boston.csv")

# %%
# parse yelp data according to parameters
def parse_data_comp_denver(list_of_data):
    # create a container to hold our parsed data
    businesses = []
    # loop through our business  
    for business in list_of_data:
        # parse each individual business into a tuple
        biz_tuple = (
                    business['name'],
                    business['location']['zip_code'],
                    business['rating'],
                    business['price'],
                    business['open_at'],
                    business['atributes']['Street Parking',
                                          'Private Lot Parking', 
                                          'Bike Parking',
                                          'Wheelchair Accessible',
                                          'Offers Military Discount',
                                          'Open to All']
                    )
        # add each individual business tuple to our data container
        businesses.append(biz_tuple)
        # put parsed result into DataFrame 'results'
        parsed_results = parse_data(data['businesses'])
        results = pd.DataFrame(parsed_results)
        # name DataFrame columns
        results.columns = ['name', 'zipcode', 'rating', 'price', 'open_at', 
                           'Street Parking','Private Lot Parking', 'Bike Parking', 
                           'Wheelchair Accessible','Offers Military Discount', 'Open to All'
                          ]
    # return the container with all of the parsed results and save file as csv
    return results.to_csv("/Competitors_Denver.csv")

# %%
# parse yelp data according to parameters
def parse_data_gp_boston(list_of_data):
    # create a container to hold our parsed data
    businesses = []
    # loop through our business  
    for business in list_of_data:
        # parse each individual business into a tuple
        biz_tuple = (business['name'],
                     business['location']['zip_code'],
                     business['rating'],
                     business['price'],
                     business['open_at']
                    )
        # add each individual business tuple to our data container
        businesses.append(biz_tuple)
        # put parsed result into DataFrame 'results'
        parsed_results = parse_data(data['businesses'])
        results = pd.DataFrame(parsed_results)
        # name DataFrame columns
        results.columns = ['name', 'zipcode', 'rating', 'price', 'open_at']
    # return the container with all of the parsed results
    return results.to_csv('/GrowthPotential_Boston.csv')

# %%
# parse yelp data according to parameters
def parse_data_gp_denver(list_of_data):
    # create a container to hold our parsed data
    businesses = []
    # loop through our business  
    for business in list_of_data:
        # parse each individual business into a tuple
        biz_tuple = (business['name'],
                     business['location']['zip_code'],
                     business['rating'],
                     business['price'],
                     business['open_at']
                    )
        # add each individual business tuple to our data container
        businesses.append(biz_tuple)
        # put parsed result into DataFrame 'results'
        parsed_results = parse_data(data['businesses'])
        results = pd.DataFrame(parsed_results)
        # name DataFrame columns
        results.columns = ['name', 'zipcode', 'rating', 'price', 'open_at']
    # return the container with all of the parsed results
    return results.to_csv('/GrowthPotential_Denver.csv')

# %%
# parse yelp data according to parameters
def parse_data_subs_boston(list_of_data):
    # create a container to hold our parsed data
    businesses = []
    # loop through our business  
    for business in list_of_data:
        # parse each individual business into a tuple
        biz_tuple = (business['name'],
                     business['location']['zip_code'],
                     business['rating'],
                     business['price'],
                     business['open_at']
                    )
        # add each individual business tuple to our data container
        businesses.append(biz_tuple)
        # put parsed result into DataFrame 'results'
        parsed_results = parse_data(data['businesses'])
        results = pd.DataFrame(parsed_results)
        # name DataFrame columns
        results.columns = ['name', 'zipcode', 'rating', 'price', 'open_at']
    # return the container with all of the parsed results
    return results.to_csv('/Substitutes_Boston.csv')

# %%
# parse yelp data according to parameters
def parse_data_subs_denver(list_of_data):
    # create a container to hold our parsed data
    businesses = []
    # loop through our business  
    for business in list_of_data:
        # parse each individual business into a tuple
        biz_tuple = (business['name'],
                     business['location']['zip_code'],
                     business['rating'],
                     business['price'],
                     business['open_at']
                    )
        # add each individual business tuple to our data container
        businesses.append(biz_tuple)
        # put parsed result into DataFrame 'results'
        parsed_results = parse_data(data['businesses'])
        results = pd.DataFrame(parsed_results)
        # name DataFrame columns
        results.columns = ['name', 'zipcode', 'rating', 'price', 'open_at']
    # return the container with all of the parsed results
    return results.to_csv('/Substitutes_Denver.csv')

# %%
# open the csv file, concat the current data, and save the data
def df_save("/yb_data.csv", results):     
    # open csv as DataFrame 
    yb_data = pd.read_csv (r"/yb_data.csv")    
    # concat results into previous DataFrame
    yb_data = pd.concat([yb_data, results]    
    # save file as csv
    yb_data.to_csv("/yb_data.csv")

# %%
# open the csv file, concat the current data, and save the data.
def df_save_comp_boston("/Competitors_Boston.csv", results):
    # open csv as DataFrame 1
    yb_data = pd.read_csv(r"/Competitors_Boston.csv")    
    # concat results into previous DataFrame
    yb_data = pd.concat([yb_data, results]    
    # save file as csv
    yb_data.to_csv("/Competitors_Boston.csv")

# %%
# open the csv file, concat the current data, and save the data.
def df_save_comp_denver("/Competitors_Denver.csv", results):
    # open csv as DataFrame 1
    yb_data = pd.read_csv(r"/Competitors_Denver.csv")    
    # concat results into previous DataFrame
    yb_data = pd.concat([yb_data, results]    
    # save file as csv
    yb_data.to_csv("/Competitors_Denver.csv")

# %%
# open the csv file, concat the current data, and save the data.
def df_save_gp_boston('/GrowthPotential_Boston.csv', results):
    # open csv as DataFrame 1
    yb_data = pd.read_csv(r'/GrowthPotential_Boston.csv')    
    # concat results into previous DataFrame
    yb_data = pd.concat([yb_data, results]    
    # save file as csv
    yb_data.to_csv('/GrowthPotential_Boston.csv')

# %%
# open the csv file, concat the current data, and save the data.
def df_save_gp_denver('/GrowthPotential_Denver.csv', results):
    # open csv as DataFrame 1
    yb_data = pd.read_csv(r'/GrowthPotential_Denver.csv')    
    # concat results into previous DataFrame
    yb_data = pd.concat([yb_data, results]    
    # save file as csv
    yb_data.to_csv('/GrowthPotential_Denver.csv')

# %%
# open the csv file, concat the current data, and save the data.
def df_save_subs_boston('/Substitutes_Boston.csv', results):
    # open csv as DataFrame 1
    yb_data = pd.read_csv(r'/Substitutes_Boston.csv')    
    # concat results into previous DataFrame
    yb_data = pd.concat([yb_data, results]    
    # save file as csv
    yb_data.to_csv('/Substitutes_Boston.csv')

# %%
# open the csv file, concat the current data, and save the data.
def df_save_subs_denver('/Substitutes_Denver.csv', results):
    # open csv as DataFrame 1
    yb_data = pd.read_csv(r'/Substitutes_Denver.csv')    
    # concat results into previous DataFrame
    yb_data = pd.concat([yb_data, results]    
    # save file as csv
    yb_data.to_csv('/Substitutes_Denver.csv')
